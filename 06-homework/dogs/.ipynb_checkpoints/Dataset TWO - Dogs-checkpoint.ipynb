# %% [markdown]
# # Homework 6, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
#xcel_data_df = pandas.read_excel('records.xlsx', sheet_name='Employees'
df = pd.read_excel('NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx').head(3000)

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.

# %%
df.shape
# Out:
# (3000, 15)

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %%
#Each row is an dog licesed NYC. Animal Name is the dog's name and Animal Gender  is the dog's gender

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %%
#what are the most popular name?
#what are the most popular color?
#If people prefer tto have more female than male dogs?
#The most popular breed

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df.groupby('Primary Breed')['Primary Breed'].count().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Primary Breed'>

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown

# %%
df[df['Primary Breed'] != 'Unknown'].groupby('Primary Breed')['Primary Breed'].count().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Primary Breed'>

# %% [markdown]
# ## What are the most popular dog names?

# %%
#grouped = df.groupby('mygroups').sum().reset_index()
#grouped.sort_values('mygroups', ascending=False)

#grouped = df.groupby('Animal Name').sum().reset_index()
#grouped.sort_values('Animal Name', ascending=False )
df.groupby('Animal Name')['Animal Name'].count().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Animal Name'>

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df['Animal Name'].isin(['Max', "Maxwell"])].groupby('Animal Name')['Animal Name'].count().sort_values(ascending=False).head(10)
# Out:
# Animal Name
# Max        19
# Maxwell     1
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## What percentage of dogs are guard dogs?
#
# Check out the documentation for [value counts](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html).

# %%
#df.gender.value_counts(normalize=True) * 100
df[df['Guard or Trained'].isin(['Yes'])]
# Out:
#       Owner Zip Code                Animal Name Animal Gender  \
# 2363           10014                     Truman             M
# 2702           10014  Bojangles Swagu Rosenberg             M
# 2871           11361                    Dorofey             M
#
#          Primary Breed           Secondary Breed Animal Dominant Color  \
# 2363           Unknown  Chinese Crested/terrier                  WHITE
# 2702  Poodle, Standard                       NaN               Apricot
# 2871           Unknown     black russian terrier                 BLACK
#
#      Animal Secondary Color Animal Third Color Animal Birth Spayed or Neut  \
# 2363                  BLACK               GRAY   2010-12-01            Yes
# 2702                  Blond                Tan   2014-03-01            Yes
# 2871                    NaN                NaN   2010-01-01             No
#
#      Guard or Trained Vaccinated        Application Date License Issued Date  \
# ...

# %% [markdown]
# ## What are the actual numbers?

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`

# %% [markdown]
# ## Fill in all of those empty "Guard or Trained" columns with "No"
#
# Then check your result with another `.value_counts()`

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
df[df['Guard or Trained'].isin(['Yes'])].groupby('Primary Breed')['Primary Breed'].count().sort_values(ascending=False).head(10)
# Out:
# Primary Breed
# Unknown             2
# Poodle, Standard    1
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
df['year'] = df['Animal Birth'].dt.year.head()
# Out:
#       Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0              10024     BLUE MACK             M               Unknown
# 1              10461  Indie Zephir             M            Rottweiler
# 2              10013         Bilal             M  Australian Cattledog
# 3              10025         Buddy             M               Unknown
# 4              10013           Ali             M               Basenji
# ...              ...           ...           ...                   ...
# 2995           10022        RASCAL             M  Jack Russell Terrier
# 2996           10011        Chanel             F              Papillon
# 2997           10016    MURPHY                 M                Beagle
# 2998           10012        Tucker             M     Beagle Crossbreed
# 2999           11209        Sophie             F               Unknown
#
#      Secondary Breed Animal Dominant Color Animal Secondary Color  \
# ...

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
df['age'] = 2021 - df['year'] 
df.age.mean()
# Out:
# 9.8

# %% [markdown]
# # Joining data together

# %%
df_zipcodes = pd.read_csv("zipcodes-neighborhoods.csv")
df_zipcodes
# Out:
#                  neighborhood    zip        borough
# 0               Central Bronx  10453          Bronx
# 1               Central Bronx  10457          Bronx
# 2               Central Bronx  10460          Bronx
# 3      Bronx Park and Fordham  10458          Bronx
# 4      Bronx Park and Fordham  10467          Bronx
# ..                        ...    ...            ...
# 173               South Shore  10312  Staten Island
# 174  Stapleton and St. George  10301  Staten Island
# 175  Stapleton and St. George  10304  Staten Island
# 176  Stapleton and St. George  10305  Staten Island
# 177                Mid-Island  10314  Staten Island
#
# [178 rows x 3 columns]

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
df = df.merge(df_zipcodes, left_on='Owner Zip Code', right_on='zip')

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?

# %%
df[df['borough'] == 'Bronx'].groupby('Animal Name')['Animal Name'].count().sort_values(ascending=False).head(1)
# Out:
# Series([], Name: Animal Name, dtype: int64)

# %%
df[df['borough'] == 'Brooklyn'].groupby('Animal Name')['Animal Name'].count().sort_values(ascending=False).head(1)
# Out:
# Animal Name
# Bella    7
# Name: Animal Name, dtype: int64

# %%
df[df['neighborhood'] == 'Upper East Side'].groupby('Animal Name')['Animal Name'].count().sort_values(ascending=False).head(1)
# Out:
# Animal Name
# Charlie    4
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?

# %%
df_grouped_by_neighborhoods = df.groupby(['neighborhood','Primary Breed'])

# %%
df_grouped_by_neighborhoods[['Primary Breed']].count().reset_index(level= 'Primary Breed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-f405aedcdd21> in <module>
# ----> 1 df_grouped_by_neighborhoods[['Primary Breed']].count().reset_index(level= 'Primary Breed')
#
# ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5014                 # to ndarray and maybe infer different dtype
#    5015                 level_values = maybe_casted_values(lev, lab)
# -> 5016                 new_obj.insert(0, name, level_values)
#    5017
#    5018         new_obj.index = new_index
#
# ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# ...

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?

# %% [markdown]
# ## Make a new column called monochrome that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.

# %% [markdown]
# ## What percentage of dogs are not guard dogs?
